# %%
import random
import json
import os
from ollama import chat
from ollama import ChatResponse

# %%
# Ollama model name
model_name = "qwen2.5-coder:32b"

# %% [markdown]
# #### For Critical Vulnerabilities

# %%
# Programming languages
languages = [
    "C", "JAVA", "PYTHON", "SQL", "C#", "JAVASCRIPT", "RUBY",
    "TYPESCRIPT", "C++", "KOTLIN", "RUST", "GO", "PHP", "SCALA"
]

# Difficulty levels
difficulties = ["easy", "medium", "hard", "very hard"]

# Common cybersecurity attacks
attacks = [
    "SQL Injection",
    "Cross-Site Scripting (XSS)",
    "Command Injection",
    "Buffer Overflow",
    "Broken Authentication",
    "Insecure Deserialization",
    "Cross-Site Request Forgery (CSRF)",
    "Path Traversal",
    "Remote Code Execution (RCE)",
    "Privilege Escalation"
]

code_types = ["complete code file", "code snippet", "function", "class"]

# %%
# Prompt template
prompt_template = """
Given the following inputs:
- Attack Type: {attack_type}
- Programming Language: {language}
- Code Type: {code_type}
- Vulnerability Detection Difficulty: {difficulty}

Your task is to:
1. Generate a {code_type} in the given language that contains a vulnerability matching the described attack type and identification difficulty level.
2. Evaluate the vulnerability and provide a realistic CVSS score as a float (e.g., 7.5).

VERY IMPORTANT:
- Output ONLY a valid JSON object.
- Do NOT add any explanation, markdown, comments, or additional text.
- Escape all double quotes correctly.
- The code must go inside the "input" key as a string.
- The CVSS score must go inside the "output" key and should be a float number only.
- The attack type must go inside the "output" key and should be a string only.

JSON FORMAT EXAMPLE:
{{
    "input": "# Python example\\ndef unsafe():\\n    eval(input(\\\"Enter command: \\\"))",
    "output": {{
        "score": 8.2,
        "type": "{attack_type}"
        }}
}}

Now generate a similar JSON for:
- Attack Type: {attack_type}
- Programming Language: {language}
- Difficulty Level: {difficulty}
- Code Type: {code_type}
"""

# %%
# Output directory
os.makedirs("Phase-2-Data", exist_ok=True)

# %%
# Retry logic
MAX_RETRIES = 2

# %%
# System + few-shot prompts
system_prompt = (
    "You are a cybersecurity code generator.\n"
    "You must always output ONLY one valid JSON object.\n"
    "No markdown, no extra text, no code blocks, no preamble.\n"
    "Just return clean JSON like: {\"input\": \"<code>\", \"output\": <cvss>}"
)
few_shot = {
    'role': 'user',
    'content': (
        "Example:\n"
        "{\n"
        "  \"input\": \"# Python example\\ndef unsafe():\\n    eval(input(\\\"Enter command: \\\"))\",\n"
        "  \"output\": 8.2\n"
        "}"
    )
}

# %%
# Main loop
for language in languages:
    print(f"\nGenerating for: {language}")
    results = {}

    for i in range(25):
        attack = random.choice(attacks)
        difficulty = random.choice(difficulties)
        code_type = random.choice(code_types)
        user_prompt = prompt_template.format(attack_type=attack, language=language, difficulty=difficulty, code_type=code_type)

        for attempt in range(MAX_RETRIES):
            try:
                response: ChatResponse = chat(model=model_name, messages=[
                    {'role': 'system', 'content': system_prompt},
                    few_shot,
                    {'role': 'user', 'content': user_prompt}
                ])

                reply = response['message']['content'].strip()
                parsed_json = json.loads(reply)

                results[f"{language.lower()}_{i}"] = parsed_json
                print(f"[{language}] Example {i+1}/25 - Success")
                break

            except Exception as e:
                if attempt == MAX_RETRIES - 1:
                    print(f"[{language}] Example {i+1}/25 - Failed: {e}")
                else:
                    print(f"Retrying [{language}] Example {i+1} due to: {e}")
                continue

    # Save results
    with open(f"Phase-2-Data/{language.lower()}.json", "w") as f:
        json.dump(results, f, indent=4)
    print(f"Saved: Phase-2-Data/{language.lower()}.json")
# Out:
# Generating for: C
# [C] Example 1/25 - Success
# [C] Example 2/25 - Success
# [C] Example 3/25 - Success
# [C] Example 4/25 - Success
# [C] Example 5/25 - Success
# [C] Example 6/25 - Success
# [C] Example 7/25 - Success
# [C] Example 8/25 - Success
# [C] Example 9/25 - Success
# [C] Example 10/25 - Success
# [C] Example 11/25 - Success
# [C] Example 12/25 - Success
# [C] Example 13/25 - Success
# [C] Example 14/25 - Success
# [C] Example 15/25 - Success
# [C] Example 16/25 - Success
# [C] Example 17/25 - Success
# [C] Example 18/25 - Success
# [C] Example 19/25 - Success
# [C] Example 20/25 - Success
# [C] Example 21/25 - Success
# [C] Example 22/25 - Success
# [C] Example 23/25 - Success
# [C] Example 24/25 - Success
# [C] Example 25/25 - Success
# Saved: Phase-2-Data/c.json
#
# Generating for: JAVA
# [JAVA] Example 1/25 - Success
# [JAVA] Example 2/25 - Success
# [JAVA] Example 3/25 - Success
# [JAVA] Example 4/25 - Success
# [JAVA] Example 5/25 - Success
# [JAVA] Example 6/25 - Success
# [JAVA] Example 7/25 - Success
# [JAVA] Example 8/25 - Success
# [JAVA] Example 9/25 - Success
# [JAVA] Example 10/25 - Success
# [JAVA] Example 11/25 - Success
# [JAVA] Example 12/25 - Success
# [JAVA] Example 13/25 - Success
# [JAVA] Example 14/25 - Success
# [JAVA] Example 15/25 - Success
# [JAVA] Example 16/25 - Success
# [JAVA] Example 17/25 - Success
# [JAVA] Example 18/25 - Success
# [JAVA] Example 19/25 - Success
# [JAVA] Example 20/25 - Success
# [JAVA] Example 21/25 - Success
# [JAVA] Example 22/25 - Success
# [JAVA] Example 23/25 - Success
# [JAVA] Example 24/25 - Success
# [JAVA] Example 25/25 - Success
# Saved: Phase-2-Data/java.json
#
# Generating for: PYTHON
# [PYTHON] Example 1/25 - Success
# [PYTHON] Example 2/25 - Success
# [PYTHON] Example 3/25 - Success
# [PYTHON] Example 4/25 - Success
# [PYTHON] Example 5/25 - Success
# [PYTHON] Example 6/25 - Success
# [PYTHON] Example 7/25 - Success
# [PYTHON] Example 8/25 - Success
# [PYTHON] Example 9/25 - Success
# [PYTHON] Example 10/25 - Success
# [PYTHON] Example 11/25 - Success
# [PYTHON] Example 12/25 - Success
# [PYTHON] Example 13/25 - Success
# [PYTHON] Example 14/25 - Success
# [PYTHON] Example 15/25 - Success
# [PYTHON] Example 16/25 - Success
# [PYTHON] Example 17/25 - Success
# [PYTHON] Example 18/25 - Success
# [PYTHON] Example 19/25 - Success
# [PYTHON] Example 20/25 - Success
# [PYTHON] Example 21/25 - Success
# [PYTHON] Example 22/25 - Success
# [PYTHON] Example 23/25 - Success
# [PYTHON] Example 24/25 - Success
# Retrying [PYTHON] Example 25 due to: Expecting ',' delimiter: line 2 column 144 (char 145)
# [PYTHON] Example 25/25 - Success
# Saved: Phase-2-Data/python.json
#
# Generating for: SQL
# [SQL] Example 1/25 - Success
# [SQL] Example 2/25 - Success
# [SQL] Example 3/25 - Success
# [SQL] Example 4/25 - Success
# [SQL] Example 5/25 - Success
# [SQL] Example 6/25 - Success
# [SQL] Example 7/25 - Success
# [SQL] Example 8/25 - Success
# [SQL] Example 9/25 - Success
# [SQL] Example 10/25 - Success
# [SQL] Example 11/25 - Success
# [SQL] Example 12/25 - Success
# [SQL] Example 13/25 - Success
# [SQL] Example 14/25 - Success
# [SQL] Example 15/25 - Success
# [SQL] Example 16/25 - Success
# [SQL] Example 17/25 - Success
# [SQL] Example 18/25 - Success
# [SQL] Example 19/25 - Success
# [SQL] Example 20/25 - Success
# [SQL] Example 21/25 - Success
# [SQL] Example 22/25 - Success
# [SQL] Example 23/25 - Success
# [SQL] Example 24/25 - Success
# [SQL] Example 25/25 - Success
# Saved: Phase-2-Data/sql.json
#
# Generating for: C#
# [C#] Example 1/25 - Success
# [C#] Example 2/25 - Success
# [C#] Example 3/25 - Success
# [C#] Example 4/25 - Success
# [C#] Example 5/25 - Success
# [C#] Example 6/25 - Success
# [C#] Example 7/25 - Success
# [C#] Example 8/25 - Success
# [C#] Example 9/25 - Success
# [C#] Example 10/25 - Success
# [C#] Example 11/25 - Success
# [C#] Example 12/25 - Success
# [C#] Example 13/25 - Success
# [C#] Example 14/25 - Success
# [C#] Example 15/25 - Success
# [C#] Example 16/25 - Success
# [C#] Example 17/25 - Success
# [C#] Example 18/25 - Success
# [C#] Example 19/25 - Success
# [C#] Example 20/25 - Success
# [C#] Example 21/25 - Success
# [C#] Example 22/25 - Success
# [C#] Example 23/25 - Success
# [C#] Example 24/25 - Success
# [C#] Example 25/25 - Success
# Saved: Phase-2-Data/c#.json
#
# Generating for: JAVASCRIPT
# [JAVASCRIPT] Example 1/25 - Success
# [JAVASCRIPT] Example 2/25 - Success
# [JAVASCRIPT] Example 3/25 - Success
# [JAVASCRIPT] Example 4/25 - Success
# Retrying [JAVASCRIPT] Example 5 due to: Invalid \escape: line 2 column 89 (char 90)
# [JAVASCRIPT] Example 5/25 - Success
# [JAVASCRIPT] Example 6/25 - Success
# [JAVASCRIPT] Example 7/25 - Success
# [JAVASCRIPT] Example 8/25 - Success
# [JAVASCRIPT] Example 9/25 - Success
# [JAVASCRIPT] Example 10/25 - Success
# [JAVASCRIPT] Example 11/25 - Success
# [JAVASCRIPT] Example 12/25 - Success
# [JAVASCRIPT] Example 13/25 - Success
# [JAVASCRIPT] Example 14/25 - Success
# [JAVASCRIPT] Example 15/25 - Success
# [JAVASCRIPT] Example 16/25 - Success
# [JAVASCRIPT] Example 17/25 - Success
# Retrying [JAVASCRIPT] Example 18 due to: Invalid \escape: line 2 column 143 (char 144)
# [JAVASCRIPT] Example 18/25 - Failed: Invalid \escape: line 2 column 175 (char 176)
# [JAVASCRIPT] Example 19/25 - Success
# [JAVASCRIPT] Example 20/25 - Success
# [JAVASCRIPT] Example 21/25 - Success
# [JAVASCRIPT] Example 22/25 - Success
# [JAVASCRIPT] Example 23/25 - Success
# [JAVASCRIPT] Example 24/25 - Success
# [JAVASCRIPT] Example 25/25 - Success
# Saved: Phase-2-Data/javascript.json
#
# Generating for: RUBY
# [RUBY] Example 1/25 - Success
# [RUBY] Example 2/25 - Success
# [RUBY] Example 3/25 - Success
# [RUBY] Example 4/25 - Success
# [RUBY] Example 5/25 - Success
# [RUBY] Example 6/25 - Success
# [RUBY] Example 7/25 - Success
# [RUBY] Example 8/25 - Success
# [RUBY] Example 9/25 - Success
# [RUBY] Example 10/25 - Success
# [RUBY] Example 11/25 - Success
# [RUBY] Example 12/25 - Success
# [RUBY] Example 13/25 - Success
# [RUBY] Example 14/25 - Success
# [RUBY] Example 15/25 - Success
# [RUBY] Example 16/25 - Success
# [RUBY] Example 17/25 - Success
# [RUBY] Example 18/25 - Success
# [RUBY] Example 19/25 - Success
# [RUBY] Example 20/25 - Success
# [RUBY] Example 21/25 - Success
# [RUBY] Example 22/25 - Success
# [RUBY] Example 23/25 - Success
# [RUBY] Example 24/25 - Success
# [RUBY] Example 25/25 - Success
# Saved: Phase-2-Data/ruby.json
#
# Generating for: TYPESCRIPT
# [TYPESCRIPT] Example 1/25 - Success
# [TYPESCRIPT] Example 2/25 - Success
# [TYPESCRIPT] Example 3/25 - Success
# [TYPESCRIPT] Example 4/25 - Success
# [TYPESCRIPT] Example 5/25 - Success
# [TYPESCRIPT] Example 6/25 - Success
# [TYPESCRIPT] Example 7/25 - Success
# [TYPESCRIPT] Example 8/25 - Success
# [TYPESCRIPT] Example 9/25 - Success
# [TYPESCRIPT] Example 10/25 - Success
# [TYPESCRIPT] Example 11/25 - Success
# [TYPESCRIPT] Example 12/25 - Success
# [TYPESCRIPT] Example 13/25 - Success
# [TYPESCRIPT] Example 14/25 - Success
# [TYPESCRIPT] Example 15/25 - Success
# [TYPESCRIPT] Example 16/25 - Success
# [TYPESCRIPT] Example 17/25 - Success
# [TYPESCRIPT] Example 18/25 - Success
# [TYPESCRIPT] Example 19/25 - Success
# [TYPESCRIPT] Example 20/25 - Success
# [TYPESCRIPT] Example 21/25 - Success
# [TYPESCRIPT] Example 22/25 - Success
# [TYPESCRIPT] Example 23/25 - Success
# [TYPESCRIPT] Example 24/25 - Success
# [TYPESCRIPT] Example 25/25 - Success
# Saved: Phase-2-Data/typescript.json
#
# Generating for: C++
# [C++] Example 1/25 - Success
# [C++] Example 2/25 - Success
# [C++] Example 3/25 - Success
# [C++] Example 4/25 - Success
# [C++] Example 5/25 - Success
# [C++] Example 6/25 - Success
# [C++] Example 7/25 - Success
# [C++] Example 8/25 - Success
# [C++] Example 9/25 - Success
# [C++] Example 10/25 - Success
# [C++] Example 11/25 - Success
# [C++] Example 12/25 - Success
# [C++] Example 13/25 - Success
# [C++] Example 14/25 - Success
# [C++] Example 15/25 - Success
# [C++] Example 16/25 - Success
# [C++] Example 17/25 - Success
# [C++] Example 18/25 - Success
# [C++] Example 19/25 - Success
# [C++] Example 20/25 - Success
# [C++] Example 21/25 - Success
# [C++] Example 22/25 - Success
# [C++] Example 23/25 - Success
# [C++] Example 24/25 - Success
# [C++] Example 25/25 - Success
# Saved: Phase-2-Data/c++.json
#
# Generating for: KOTLIN
# [KOTLIN] Example 1/25 - Success
# [KOTLIN] Example 2/25 - Success
# [KOTLIN] Example 3/25 - Success
# [KOTLIN] Example 4/25 - Success
# [KOTLIN] Example 5/25 - Success
# [KOTLIN] Example 6/25 - Success
# [KOTLIN] Example 7/25 - Success
# [KOTLIN] Example 8/25 - Success
# [KOTLIN] Example 9/25 - Success
# [KOTLIN] Example 10/25 - Success
# [KOTLIN] Example 11/25 - Success
# [KOTLIN] Example 12/25 - Success
# [KOTLIN] Example 13/25 - Success
# [KOTLIN] Example 14/25 - Success
# [KOTLIN] Example 15/25 - Success
# [KOTLIN] Example 16/25 - Success
# [KOTLIN] Example 17/25 - Success
# [KOTLIN] Example 18/25 - Success
# [KOTLIN] Example 19/25 - Success
# [KOTLIN] Example 20/25 - Success
# [KOTLIN] Example 21/25 - Success
# [KOTLIN] Example 22/25 - Success
# [KOTLIN] Example 23/25 - Success
# [KOTLIN] Example 24/25 - Success
# [KOTLIN] Example 25/25 - Success
# Saved: Phase-2-Data/kotlin.json
#
# Generating for: RUST
# [RUST] Example 1/25 - Success
# [RUST] Example 2/25 - Success
# [RUST] Example 3/25 - Success
# [RUST] Example 4/25 - Success
# [RUST] Example 5/25 - Success
# [RUST] Example 6/25 - Success
# [RUST] Example 7/25 - Success
# [RUST] Example 8/25 - Success
# [RUST] Example 9/25 - Success
# [RUST] Example 10/25 - Success
# [RUST] Example 11/25 - Success
# [RUST] Example 12/25 - Success
# [RUST] Example 13/25 - Success
# [RUST] Example 14/25 - Success
# [RUST] Example 15/25 - Success
# [RUST] Example 16/25 - Success
# Retrying [RUST] Example 17 due to: Invalid \escape: line 2 column 304 (char 305)
# [RUST] Example 17/25 - Failed: Invalid \escape: line 2 column 242 (char 243)
# [RUST] Example 18/25 - Success
# [RUST] Example 19/25 - Success
# [RUST] Example 20/25 - Success
# [RUST] Example 21/25 - Success
# [RUST] Example 22/25 - Success
# [RUST] Example 23/25 - Success
# [RUST] Example 24/25 - Success
# [RUST] Example 25/25 - Success
# Saved: Phase-2-Data/rust.json
#
# Generating for: GO
# [GO] Example 1/25 - Success
# [GO] Example 2/25 - Success
# [GO] Example 3/25 - Success
# [GO] Example 4/25 - Success
# [GO] Example 5/25 - Success
# [GO] Example 6/25 - Success
# [GO] Example 7/25 - Success
# [GO] Example 8/25 - Success
# [GO] Example 9/25 - Success
# [GO] Example 10/25 - Success
# [GO] Example 11/25 - Success
# [GO] Example 12/25 - Success
# [GO] Example 13/25 - Success
# [GO] Example 14/25 - Success
# [GO] Example 15/25 - Success
# [GO] Example 16/25 - Success
# [GO] Example 17/25 - Success
# [GO] Example 18/25 - Success
# [GO] Example 19/25 - Success
# [GO] Example 20/25 - Success
# [GO] Example 21/25 - Success
# [GO] Example 22/25 - Success
# [GO] Example 23/25 - Success
# [GO] Example 24/25 - Success
# [GO] Example 25/25 - Success
# Saved: Phase-2-Data/go.json
#
# Generating for: PHP
# [PHP] Example 1/25 - Success
# [PHP] Example 2/25 - Success
# [PHP] Example 3/25 - Success
# [PHP] Example 4/25 - Success
# [PHP] Example 5/25 - Success
# [PHP] Example 6/25 - Success
# [PHP] Example 7/25 - Success
# [PHP] Example 8/25 - Success
# [PHP] Example 9/25 - Success
# [PHP] Example 10/25 - Success
# [PHP] Example 11/25 - Success
# [PHP] Example 12/25 - Success
# [PHP] Example 13/25 - Success
# [PHP] Example 14/25 - Success
# [PHP] Example 15/25 - Success
# [PHP] Example 16/25 - Success
# [PHP] Example 17/25 - Success
# [PHP] Example 18/25 - Success
# [PHP] Example 19/25 - Success
# [PHP] Example 20/25 - Success
# [PHP] Example 21/25 - Success
# [PHP] Example 22/25 - Success
# [PHP] Example 23/25 - Success
# [PHP] Example 24/25 - Success
# [PHP] Example 25/25 - Success
# Saved: Phase-2-Data/php.json
#
# Generating for: SCALA
# [SCALA] Example 1/25 - Success
# [SCALA] Example 2/25 - Success
# [SCALA] Example 3/25 - Success
# [SCALA] Example 4/25 - Success
# [SCALA] Example 5/25 - Success
# [SCALA] Example 6/25 - Success
# [SCALA] Example 7/25 - Success
# [SCALA] Example 8/25 - Success
# [SCALA] Example 9/25 - Success
# [SCALA] Example 10/25 - Success
# [SCALA] Example 11/25 - Success
# [SCALA] Example 12/25 - Success
# [SCALA] Example 13/25 - Success
# [SCALA] Example 14/25 - Success
# [SCALA] Example 15/25 - Success
# [SCALA] Example 16/25 - Success
# [SCALA] Example 17/25 - Success
# [SCALA] Example 18/25 - Success
# [SCALA] Example 19/25 - Success
# [SCALA] Example 20/25 - Success
# [SCALA] Example 21/25 - Success
# [SCALA] Example 22/25 - Success
# [SCALA] Example 23/25 - Success
# [SCALA] Example 24/25 - Success
# [SCALA] Example 25/25 - Success
# Saved: Phase-2-Data/scala.json

# %% [markdown]
# #### For Mild Vulnerabilities

# %%
# Programming languages
languages = [
    "C", "JAVA", "PYTHON", "SQL", "C#", "JAVASCRIPT", "RUBY",
    "TYPESCRIPT", "C++", "KOTLIN", "RUST", "GO", "PHP", "SCALA"
]

# Difficulty levels
difficulties = ["easy", "medium", "hard", "very hard"]

# Common cybersecurity attacks
attacks = [
    "Information Disclosure (Low Severity)",
    "Denial-of-Service (DoS) - Low Impact",
    "Clickjacking (Low Severity)",
    "Server-Side Request Forgery (SSRF) - Limited Scope",
    "Session Fixation (Low Severity)",
    "Local File Inclusion (LFI) - Limited Scope",
    "Race Condition (Difficult to Exploit)",
    "Open Redirect",
    "HTTP Response Splitting",
    "Missing Security Headers"
]

code_types = ["complete code file", "code snippet", "function", "class"]

# %%
# Prompt template
prompt_template = """
Given the following inputs:
- Attack Type: {attack_type}
- Programming Language: {language}
- Code Type: {code_type}
- Vulnerability Detection Difficulty: {difficulty}

Your task is to:
1. Generate a {code_type} in the given language that contains a vulnerability matching the described attack type and identification difficulty level.
2. Evaluate the vulnerability and provide a realistic CVSS score as a float (e.g., 7.5).

VERY IMPORTANT:
- Output ONLY a valid JSON object.
- Do NOT add any explanation, markdown, comments, or additional text.
- Escape all double quotes correctly.
- The code must go inside the "input" key as a string.
- The CVSS score must go inside the "output" key and should be a float number only.
- The attack type must go inside the "output" key and should be a string only.

JSON FORMAT EXAMPLE:
{{
    "input": "# Python example\\ndef unsafe():\\n    eval(input(\\\"Enter command: \\\"))",
    "output": {{
        "score": 4.2,
        "type": "{attack_type}"
        }}
}}

Now generate a similar JSON for:
- Attack Type: {attack_type}
- Programming Language: {language}
- Difficulty Level: {difficulty}
- Code Type: {code_type}
"""

# %%
# Output directory
os.makedirs("Phase-2-Data", exist_ok=True)

# %%
# Retry logic
MAX_RETRIES = 2

# %%
# System + few-shot prompts
system_prompt = (
    "You are a cybersecurity code generator.\n"
    "You must always output ONLY one valid JSON object.\n"
    "No markdown, no extra text, no code blocks, no preamble.\n"
    "Just return clean JSON like: {\"input\": \"<code>\", \"output\": <cvss>}"
)
few_shot = {
    'role': 'user',
    'content': (
        "Example:\n"
        "{\n"
        "  \"input\": \"# Python example\\ndef unsafe():\\n    eval(input(\\\"Enter command: \\\"))\",\n"
        "  \"output\": 4.2\n"
        "}"
    )
}

# %%
# Main loop
for language in languages:
    print(f"\nGenerating for: {language}")
    results = {}

    for i in range(25, 50):
        attack = random.choice(attacks)
        difficulty = random.choice(difficulties)
        code_type = random.choice(code_types)
        user_prompt = prompt_template.format(attack_type=attack, language=language, difficulty=difficulty, code_type=code_type)

        for attempt in range(MAX_RETRIES):
            try:
                response: ChatResponse = chat(model=model_name, messages=[
                    {'role': 'system', 'content': system_prompt},
                    few_shot,
                    {'role': 'user', 'content': user_prompt}
                ])

                reply = response['message']['content'].strip()
                parsed_json = json.loads(reply)

                results[f"{language.lower()}_{i}"] = parsed_json
                print(f"[{language}] Example {i+1}/50 - Success")
                break

            except Exception as e:
                if attempt == MAX_RETRIES - 1:
                    print(f"[{language}] Example {i+1}/50 - Failed: {e}")
                else:
                    print(f"Retrying [{language}] Example {i+1} due to: {e}")
                continue

    # Save results
    file_path = f"Phase-2-Data/{language.lower()}.json"

    if os.path.exists(file_path):
        with open(file_path, "r") as f:
            try:
                existing_data = json.load(f)
            except json.JSONDecodeError:
                print(f"Error decoding JSON from {file_path}. Starting with empty data.")
                existing_data = {}
    else:
        existing_data = {}

    existing_data.update(results)

    with open(file_path, "w") as f:
        json.dump(existing_data, f, indent=4)

    print(f"Saved: {file_path}")
# Out:
# Generating for: C
# [C] Example 26/50 - Success
# [C] Example 27/50 - Success
# [C] Example 28/50 - Success
# [C] Example 29/50 - Success
# [C] Example 30/50 - Success
# [C] Example 31/50 - Success
# [C] Example 32/50 - Success
# [C] Example 33/50 - Success
# [C] Example 34/50 - Success
# [C] Example 35/50 - Success
# [C] Example 36/50 - Success
# [C] Example 37/50 - Success
# [C] Example 38/50 - Success
# [C] Example 39/50 - Success
# [C] Example 40/50 - Success
# [C] Example 41/50 - Success
# [C] Example 42/50 - Success
# [C] Example 43/50 - Success
# [C] Example 44/50 - Success
# [C] Example 45/50 - Success
# [C] Example 46/50 - Success
# [C] Example 47/50 - Success
# [C] Example 48/50 - Success
# [C] Example 49/50 - Success
# [C] Example 50/50 - Success
# Saved: Phase-2-Data/c.json
#
# Generating for: JAVA
# [JAVA] Example 26/50 - Success
# [JAVA] Example 27/50 - Success
# [JAVA] Example 28/50 - Success
# [JAVA] Example 29/50 - Success
# [JAVA] Example 30/50 - Success
# [JAVA] Example 31/50 - Success
# [JAVA] Example 32/50 - Success
# [JAVA] Example 33/50 - Success
# [JAVA] Example 34/50 - Success
# [JAVA] Example 35/50 - Success
# [JAVA] Example 36/50 - Success
# [JAVA] Example 37/50 - Success
# [JAVA] Example 38/50 - Success
# [JAVA] Example 39/50 - Success
# [JAVA] Example 40/50 - Success
# [JAVA] Example 41/50 - Success
# [JAVA] Example 42/50 - Success
# [JAVA] Example 43/50 - Success
# [JAVA] Example 44/50 - Success
# [JAVA] Example 45/50 - Success
# [JAVA] Example 46/50 - Success
# [JAVA] Example 47/50 - Success
# [JAVA] Example 48/50 - Success
# [JAVA] Example 49/50 - Success
# [JAVA] Example 50/50 - Success
# Saved: Phase-2-Data/java.json
#
# Generating for: PYTHON
# [PYTHON] Example 26/50 - Success
# [PYTHON] Example 27/50 - Success
# [PYTHON] Example 28/50 - Success
# [PYTHON] Example 29/50 - Success
# [PYTHON] Example 30/50 - Success
# [PYTHON] Example 31/50 - Success
# [PYTHON] Example 32/50 - Success
# [PYTHON] Example 33/50 - Success
# [PYTHON] Example 34/50 - Success
# [PYTHON] Example 35/50 - Success
# [PYTHON] Example 36/50 - Success
# [PYTHON] Example 37/50 - Success
# [PYTHON] Example 38/50 - Success
# [PYTHON] Example 39/50 - Success
# [PYTHON] Example 40/50 - Success
# [PYTHON] Example 41/50 - Success
# [PYTHON] Example 42/50 - Success
# [PYTHON] Example 43/50 - Success
# [PYTHON] Example 44/50 - Success
# [PYTHON] Example 45/50 - Success
# [PYTHON] Example 46/50 - Success
# [PYTHON] Example 47/50 - Success
# [PYTHON] Example 48/50 - Success
# [PYTHON] Example 49/50 - Success
# [PYTHON] Example 50/50 - Success
# Saved: Phase-2-Data/python.json
#
# Generating for: SQL
# [SQL] Example 26/50 - Success
# [SQL] Example 27/50 - Success
# [SQL] Example 28/50 - Success
# [SQL] Example 29/50 - Success
# [SQL] Example 30/50 - Success
# [SQL] Example 31/50 - Success
# [SQL] Example 32/50 - Success
# [SQL] Example 33/50 - Success
# [SQL] Example 34/50 - Success
# [SQL] Example 35/50 - Success
# [SQL] Example 36/50 - Success
# [SQL] Example 37/50 - Success
# [SQL] Example 38/50 - Success
# [SQL] Example 39/50 - Success
# Retrying [SQL] Example 40 due to: Invalid \escape: line 2 column 136 (char 137)
# [SQL] Example 40/50 - Success
# Retrying [SQL] Example 41 due to: Invalid \escape: line 2 column 72 (char 73)
# [SQL] Example 41/50 - Success
# Retrying [SQL] Example 42 due to: Expecting ',' delimiter: line 2 column 78 (char 79)
# [SQL] Example 42/50 - Success
# Retrying [SQL] Example 43 due to: Expecting ',' delimiter: line 2 column 57 (char 58)
# [SQL] Example 43/50 - Success
# [SQL] Example 44/50 - Success
# [SQL] Example 45/50 - Success
# [SQL] Example 46/50 - Success
# [SQL] Example 47/50 - Success
# [SQL] Example 48/50 - Success
# [SQL] Example 49/50 - Success
# [SQL] Example 50/50 - Success
# Saved: Phase-2-Data/sql.json
#
# Generating for: C#
# [C#] Example 26/50 - Success
# [C#] Example 27/50 - Success
# [C#] Example 28/50 - Success
# [C#] Example 29/50 - Success
# [C#] Example 30/50 - Success
# [C#] Example 31/50 - Success
# [C#] Example 32/50 - Success
# [C#] Example 33/50 - Success
# [C#] Example 34/50 - Success
# [C#] Example 35/50 - Success
# [C#] Example 36/50 - Success
# [C#] Example 37/50 - Success
# [C#] Example 38/50 - Success
# [C#] Example 39/50 - Success
# [C#] Example 40/50 - Success
# [C#] Example 41/50 - Success
# [C#] Example 42/50 - Success
# [C#] Example 43/50 - Success
# [C#] Example 44/50 - Success
# [C#] Example 45/50 - Success
# [C#] Example 46/50 - Success
# [C#] Example 47/50 - Success
# [C#] Example 48/50 - Success
# [C#] Example 49/50 - Success
# [C#] Example 50/50 - Success
# Saved: Phase-2-Data/c#.json
#
# Generating for: JAVASCRIPT
# [JAVASCRIPT] Example 26/50 - Success
# [JAVASCRIPT] Example 27/50 - Success
# [JAVASCRIPT] Example 28/50 - Success
# [JAVASCRIPT] Example 29/50 - Success
# [JAVASCRIPT] Example 30/50 - Success
# [JAVASCRIPT] Example 31/50 - Success
# [JAVASCRIPT] Example 32/50 - Success
# [JAVASCRIPT] Example 33/50 - Success
# [JAVASCRIPT] Example 34/50 - Success
# [JAVASCRIPT] Example 35/50 - Success
# [JAVASCRIPT] Example 36/50 - Success
# [JAVASCRIPT] Example 37/50 - Success
# [JAVASCRIPT] Example 38/50 - Success
# [JAVASCRIPT] Example 39/50 - Success
# [JAVASCRIPT] Example 40/50 - Success
# [JAVASCRIPT] Example 41/50 - Success
# [JAVASCRIPT] Example 42/50 - Success
# [JAVASCRIPT] Example 43/50 - Success
# [JAVASCRIPT] Example 44/50 - Success
# [JAVASCRIPT] Example 45/50 - Success
# [JAVASCRIPT] Example 46/50 - Success
# [JAVASCRIPT] Example 47/50 - Success
# [JAVASCRIPT] Example 48/50 - Success
# [JAVASCRIPT] Example 49/50 - Success
# [JAVASCRIPT] Example 50/50 - Success
# Saved: Phase-2-Data/javascript.json
#
# Generating for: RUBY
# [RUBY] Example 26/50 - Success
# [RUBY] Example 27/50 - Success
# [RUBY] Example 28/50 - Success
# [RUBY] Example 29/50 - Success
# [RUBY] Example 30/50 - Success
# [RUBY] Example 31/50 - Success
# [RUBY] Example 32/50 - Success
# [RUBY] Example 33/50 - Success
# [RUBY] Example 34/50 - Success
# [RUBY] Example 35/50 - Success
# Retrying [RUBY] Example 36 due to: Invalid \escape: line 2 column 122 (char 123)
# [RUBY] Example 36/50 - Success
# [RUBY] Example 37/50 - Success
# [RUBY] Example 38/50 - Success
# [RUBY] Example 39/50 - Success
# [RUBY] Example 40/50 - Success
# [RUBY] Example 41/50 - Success
# [RUBY] Example 42/50 - Success
# [RUBY] Example 43/50 - Success
# [RUBY] Example 44/50 - Success
# [RUBY] Example 45/50 - Success
# [RUBY] Example 46/50 - Success
# [RUBY] Example 47/50 - Success
# [RUBY] Example 48/50 - Success
# [RUBY] Example 49/50 - Success
# [RUBY] Example 50/50 - Success
# Saved: Phase-2-Data/ruby.json
#
# Generating for: TYPESCRIPT
# [TYPESCRIPT] Example 26/50 - Success
# [TYPESCRIPT] Example 27/50 - Success
# [TYPESCRIPT] Example 28/50 - Success
# [TYPESCRIPT] Example 29/50 - Success
# [TYPESCRIPT] Example 30/50 - Success
# [TYPESCRIPT] Example 31/50 - Success
# [TYPESCRIPT] Example 32/50 - Success
# [TYPESCRIPT] Example 33/50 - Success
# [TYPESCRIPT] Example 34/50 - Success
# [TYPESCRIPT] Example 35/50 - Success
# [TYPESCRIPT] Example 36/50 - Success
# [TYPESCRIPT] Example 37/50 - Success
# [TYPESCRIPT] Example 38/50 - Success
# [TYPESCRIPT] Example 39/50 - Success
# [TYPESCRIPT] Example 40/50 - Success
# [TYPESCRIPT] Example 41/50 - Success
# [TYPESCRIPT] Example 42/50 - Success
# [TYPESCRIPT] Example 43/50 - Success
# [TYPESCRIPT] Example 44/50 - Success
# [TYPESCRIPT] Example 45/50 - Success
# [TYPESCRIPT] Example 46/50 - Success
# [TYPESCRIPT] Example 47/50 - Success
# [TYPESCRIPT] Example 48/50 - Success
# [TYPESCRIPT] Example 49/50 - Success
# [TYPESCRIPT] Example 50/50 - Success
# Saved: Phase-2-Data/typescript.json
#
# Generating for: C++
# [C++] Example 26/50 - Success
# [C++] Example 27/50 - Success
# [C++] Example 28/50 - Success
# [C++] Example 29/50 - Success
# [C++] Example 30/50 - Success
# [C++] Example 31/50 - Success
# [C++] Example 32/50 - Success
# [C++] Example 33/50 - Success
# [C++] Example 34/50 - Success
# [C++] Example 35/50 - Success
# [C++] Example 36/50 - Success
# [C++] Example 37/50 - Success
# [C++] Example 38/50 - Success
# [C++] Example 39/50 - Success
# [C++] Example 40/50 - Success
# [C++] Example 41/50 - Success
# [C++] Example 42/50 - Success
# [C++] Example 43/50 - Success
# [C++] Example 44/50 - Success
# [C++] Example 45/50 - Success
# [C++] Example 46/50 - Success
# [C++] Example 47/50 - Success
# [C++] Example 48/50 - Success
# [C++] Example 49/50 - Success
# [C++] Example 50/50 - Success
# Saved: Phase-2-Data/c++.json
#
# Generating for: KOTLIN
# [KOTLIN] Example 26/50 - Success
# Retrying [KOTLIN] Example 27 due to: Invalid \escape: line 2 column 228 (char 229)
# [KOTLIN] Example 27/50 - Success
# [KOTLIN] Example 28/50 - Success
# [KOTLIN] Example 29/50 - Success
# [KOTLIN] Example 30/50 - Success
# Retrying [KOTLIN] Example 31 due to: Invalid \escape: line 2 column 200 (char 201)
# [KOTLIN] Example 31/50 - Success
# [KOTLIN] Example 32/50 - Success
# [KOTLIN] Example 33/50 - Success
# [KOTLIN] Example 34/50 - Success
# [KOTLIN] Example 35/50 - Success
# [KOTLIN] Example 36/50 - Success
# [KOTLIN] Example 37/50 - Success
# Retrying [KOTLIN] Example 38 due to: Invalid \escape: line 2 column 181 (char 182)
# [KOTLIN] Example 38/50 - Success
# [KOTLIN] Example 39/50 - Success
# [KOTLIN] Example 40/50 - Success
# [KOTLIN] Example 41/50 - Success
# [KOTLIN] Example 42/50 - Success
# [KOTLIN] Example 43/50 - Success
# [KOTLIN] Example 44/50 - Success
# [KOTLIN] Example 45/50 - Success
# [KOTLIN] Example 46/50 - Success
# [KOTLIN] Example 47/50 - Success
# [KOTLIN] Example 48/50 - Success
# [KOTLIN] Example 49/50 - Success
# [KOTLIN] Example 50/50 - Success
# Saved: Phase-2-Data/kotlin.json
#
# Generating for: RUST
# [RUST] Example 26/50 - Success
# [RUST] Example 27/50 - Success
# [RUST] Example 28/50 - Success
# [RUST] Example 29/50 - Success
# [RUST] Example 30/50 - Success
# [RUST] Example 31/50 - Success
# [RUST] Example 32/50 - Success
# [RUST] Example 33/50 - Success
# [RUST] Example 34/50 - Success
# [RUST] Example 35/50 - Success
# [RUST] Example 36/50 - Success
# Retrying [RUST] Example 37 due to: Expecting property name enclosed in double quotes: line 2 column 575 (char 576)
# [RUST] Example 37/50 - Failed: Expecting property name enclosed in double quotes: line 2 column 958 (char 959)
# [RUST] Example 38/50 - Success
# [RUST] Example 39/50 - Success
# [RUST] Example 40/50 - Success
# [RUST] Example 41/50 - Success
# [RUST] Example 42/50 - Success
# [RUST] Example 43/50 - Success
# [RUST] Example 44/50 - Success
# [RUST] Example 45/50 - Success
# [RUST] Example 46/50 - Success
# [RUST] Example 47/50 - Success
# [RUST] Example 48/50 - Success
# [RUST] Example 49/50 - Success
# [RUST] Example 50/50 - Success
# Saved: Phase-2-Data/rust.json
#
# Generating for: GO
# [GO] Example 26/50 - Success
# [GO] Example 27/50 - Success
# [GO] Example 28/50 - Success
# [GO] Example 29/50 - Success
# [GO] Example 30/50 - Success
# [GO] Example 31/50 - Success
# [GO] Example 32/50 - Success
# [GO] Example 33/50 - Success
# [GO] Example 34/50 - Success
# [GO] Example 35/50 - Success
# [GO] Example 36/50 - Success
# [GO] Example 37/50 - Success
# [GO] Example 38/50 - Success
# [GO] Example 39/50 - Success
# [GO] Example 40/50 - Success
# [GO] Example 41/50 - Success
# [GO] Example 42/50 - Success
# [GO] Example 43/50 - Success
# [GO] Example 44/50 - Success
# [GO] Example 45/50 - Success
# [GO] Example 46/50 - Success
# [GO] Example 47/50 - Success
# [GO] Example 48/50 - Success
# [GO] Example 49/50 - Success
# [GO] Example 50/50 - Success
# Saved: Phase-2-Data/go.json
#
# Generating for: PHP
# Retrying [PHP] Example 26 due to: Invalid \escape: line 2 column 229 (char 230)
# [PHP] Example 26/50 - Success
# [PHP] Example 27/50 - Success
# [PHP] Example 28/50 - Success
# [PHP] Example 29/50 - Success
# [PHP] Example 30/50 - Success
# [PHP] Example 31/50 - Success
# [PHP] Example 32/50 - Success
# [PHP] Example 33/50 - Success
# [PHP] Example 34/50 - Success
# [PHP] Example 35/50 - Success
# [PHP] Example 36/50 - Success
# [PHP] Example 37/50 - Success
# [PHP] Example 38/50 - Success
# [PHP] Example 39/50 - Success
# [PHP] Example 40/50 - Success
# [PHP] Example 41/50 - Success
# [PHP] Example 42/50 - Success
# [PHP] Example 43/50 - Success
# [PHP] Example 44/50 - Success
# Retrying [PHP] Example 45 due to: Invalid \escape: line 2 column 67 (char 68)
# [PHP] Example 45/50 - Success
# [PHP] Example 46/50 - Success
# [PHP] Example 47/50 - Success
# [PHP] Example 48/50 - Success
# [PHP] Example 49/50 - Success
# [PHP] Example 50/50 - Success
# Saved: Phase-2-Data/php.json
#
# Generating for: SCALA
# [SCALA] Example 26/50 - Success
# [SCALA] Example 27/50 - Success
# [SCALA] Example 28/50 - Success
# [SCALA] Example 29/50 - Success
# [SCALA] Example 30/50 - Success
# [SCALA] Example 31/50 - Success
# [SCALA] Example 32/50 - Success
# [SCALA] Example 33/50 - Success
# [SCALA] Example 34/50 - Success
# [SCALA] Example 35/50 - Success
# [SCALA] Example 36/50 - Success
# [SCALA] Example 37/50 - Success
# [SCALA] Example 38/50 - Success
# [SCALA] Example 39/50 - Success
# [SCALA] Example 40/50 - Success
# [SCALA] Example 41/50 - Success
# [SCALA] Example 42/50 - Success
# [SCALA] Example 43/50 - Success
# [SCALA] Example 44/50 - Success
# [SCALA] Example 45/50 - Success
# [SCALA] Example 46/50 - Success
# [SCALA] Example 47/50 - Success
# [SCALA] Example 48/50 - Success
# [SCALA] Example 49/50 - Success
# [SCALA] Example 50/50 - Success
# Saved: Phase-2-Data/scala.json

# %% [markdown]
# #### For Safe Code

# %%
# Programming languages
languages = [
    "C", "JAVA", "PYTHON", "SQL", "C#", "JAVASCRIPT", "RUBY",
    "TYPESCRIPT", "C++", "KOTLIN", "RUST", "GO", "PHP", "SCALA"
]

code_types = ["complete code file", "code snippet", "function", "class"]

# %%
# Prompt template
prompt_template = """
Your task is to:
1. Generate a secure, production-grade {code_type} snippet in {language} that demonstrates best practices in secure coding.
2. The code must not contain any known security vulnerabilities or bad practices.
3. Use appropriate input validation, safe APIs, error handling, and other relevant security techniques depending on the language and context.

REQUIREMENTS:
- Output ONLY a valid JSON object.
- Do NOT add any explanation, markdown, comments, or additional text.
- Escape all double quotes correctly.
- The secure code must go inside the "input" key as a string.
- The "output" key must include a string "Secure" as the value of the "type" field, and the CVSS score must be 0.0 (indicating no vulnerability).

JSON FORMAT EXAMPLE:
{{
    "input": "# Python example\\ndef safe():\\n    user_input = input(\\\"Enter number: \\\")\\n    if user_input.isdigit():\\n        print(int(user_input))",
    "output": {{
        "score": 0.0,
        "type": "Secure"
    }}
}}

Now generate a similar JSON for:
- Programming Language: {language}
- Code Type: {code_type}
"""

# %%
# Output directory
os.makedirs("Phase-2-Data", exist_ok=True)

# %%
# Retry logic
MAX_RETRIES = 2

# %%
# System + few-shot prompts
system_prompt = (
    "You are a secure code generator.\n"
    "You must always output ONLY one valid JSON object.\n"
    "No markdown, no extra text, no code blocks, no preamble.\n"
    "The JSON must include an 'input' field with secure code as a string,\n"
    "and an 'output' field with 'score': 0.0 and 'type': 'Secure'."
)
few_shot = {
    'role': 'user',
    'content': (
        "Example:\n"
        "{\n"
        "  \"input\": \"# Python example\\ndef safe():\\n    user_input = input(\\\"Enter number: \\\")\\n    if user_input.isdigit():\\n        print(int(user_input))\",\n"
        "  \"output\": {\n"
        "    \"score\": 0.0,\n"
        "    \"type\": \"Secure\"\n"
        "  }\n"
        "}"
    )
}

# %%
# Main loop
for language in languages:
    print(f"\nGenerating for: {language}")
    results = {}

    for i in range(50, 90):
        code_type = random.choice(code_types)
        user_prompt = prompt_template.format(language=language, code_type=code_type)

        for attempt in range(MAX_RETRIES):
            try:
                response: ChatResponse = chat(model=model_name, messages=[
                    {'role': 'system', 'content': system_prompt},
                    few_shot,
                    {'role': 'user', 'content': user_prompt}
                ])

                reply = response['message']['content'].strip()
                parsed_json = json.loads(reply)

                results[f"{language.lower()}_{i}"] = parsed_json
                print(f"[{language}] Example {i+1}/90 - Success")
                break

            except Exception as e:
                if attempt == MAX_RETRIES - 1:
                    print(f"[{language}] Example {i+1}/90 - Failed: {e}")
                else:
                    print(f"Retrying [{language}] Example {i+1} due to: {e}")
                continue

    # Save results
    file_path = f"Phase-2-Data/{language.lower()}.json"

    if os.path.exists(file_path):
        with open(file_path, "r") as f:
            try:
                existing_data = json.load(f)
            except json.JSONDecodeError:
                print(f"Error decoding JSON from {file_path}. Starting with empty data.")
                existing_data = {}
    else:
        existing_data = {}

    existing_data.update(results)

    with open(file_path, "w") as f:
        json.dump(existing_data, f, indent=4)

    print(f"Saved: {file_path}")
# Out:
# Generating for: C
# [C] Example 51/90 - Success
# [C] Example 52/90 - Success
# [C] Example 53/90 - Success
# [C] Example 54/90 - Success
# [C] Example 55/90 - Success
# [C] Example 56/90 - Success
# [C] Example 57/90 - Success
# [C] Example 58/90 - Success
# [C] Example 59/90 - Success
# [C] Example 60/90 - Success
# [C] Example 61/90 - Success
# [C] Example 62/90 - Success
# [C] Example 63/90 - Success
# [C] Example 64/90 - Success
# [C] Example 65/90 - Success
# [C] Example 66/90 - Success
# [C] Example 67/90 - Success
# [C] Example 68/90 - Success
# [C] Example 69/90 - Success
# [C] Example 70/90 - Success
# [C] Example 71/90 - Success
# [C] Example 72/90 - Success
# [C] Example 73/90 - Success
# [C] Example 74/90 - Success
# [C] Example 75/90 - Success
# [C] Example 76/90 - Success
# [C] Example 77/90 - Success
# [C] Example 78/90 - Success
# [C] Example 79/90 - Success
# [C] Example 80/90 - Success
# [C] Example 81/90 - Success
# [C] Example 82/90 - Success
# [C] Example 83/90 - Success
# [C] Example 84/90 - Success
# [C] Example 85/90 - Success
# [C] Example 86/90 - Success
# [C] Example 87/90 - Success
# [C] Example 88/90 - Success
# [C] Example 89/90 - Success
# [C] Example 90/90 - Success
# Saved: Phase-2-Data/c.json
#
# Generating for: JAVA
# [JAVA] Example 51/90 - Success
# [JAVA] Example 52/90 - Success
# [JAVA] Example 53/90 - Success
# [JAVA] Example 54/90 - Success
# [JAVA] Example 55/90 - Success
# [JAVA] Example 56/90 - Success
# [JAVA] Example 57/90 - Success
# [JAVA] Example 58/90 - Success
# [JAVA] Example 59/90 - Success
# [JAVA] Example 60/90 - Success
# [JAVA] Example 61/90 - Success
# Retrying [JAVA] Example 62 due to: Invalid \escape: line 2 column 479 (char 480)
# [JAVA] Example 62/90 - Success
# [JAVA] Example 63/90 - Success
# [JAVA] Example 64/90 - Success
# [JAVA] Example 65/90 - Success
# [JAVA] Example 66/90 - Success
# [JAVA] Example 67/90 - Success
# [JAVA] Example 68/90 - Success
# [JAVA] Example 69/90 - Success
# [JAVA] Example 70/90 - Success
# [JAVA] Example 71/90 - Success
# [JAVA] Example 72/90 - Success
# [JAVA] Example 73/90 - Success
# [JAVA] Example 74/90 - Success
# [JAVA] Example 75/90 - Success
# [JAVA] Example 76/90 - Success
# [JAVA] Example 77/90 - Success
# [JAVA] Example 78/90 - Success
# [JAVA] Example 79/90 - Success
# [JAVA] Example 80/90 - Success
# [JAVA] Example 81/90 - Success
# [JAVA] Example 82/90 - Success
# [JAVA] Example 83/90 - Success
# [JAVA] Example 84/90 - Success
# [JAVA] Example 85/90 - Success
# [JAVA] Example 86/90 - Success
# [JAVA] Example 87/90 - Success
# [JAVA] Example 88/90 - Success
# [JAVA] Example 89/90 - Success
# [JAVA] Example 90/90 - Success
# Saved: Phase-2-Data/java.json
#
# Generating for: PYTHON
# [PYTHON] Example 51/90 - Success
# [PYTHON] Example 52/90 - Success
# [PYTHON] Example 53/90 - Success
# [PYTHON] Example 54/90 - Success
# [PYTHON] Example 55/90 - Success
# [PYTHON] Example 56/90 - Success
# [PYTHON] Example 57/90 - Success
# [PYTHON] Example 58/90 - Success
# [PYTHON] Example 59/90 - Success
# [PYTHON] Example 60/90 - Success
# [PYTHON] Example 61/90 - Success
# [PYTHON] Example 62/90 - Success
# [PYTHON] Example 63/90 - Success
# [PYTHON] Example 64/90 - Success
# [PYTHON] Example 65/90 - Success
# [PYTHON] Example 66/90 - Success
# [PYTHON] Example 67/90 - Success
# [PYTHON] Example 68/90 - Success
# [PYTHON] Example 69/90 - Success
# [PYTHON] Example 70/90 - Success
# [PYTHON] Example 71/90 - Success
# [PYTHON] Example 72/90 - Success
# [PYTHON] Example 73/90 - Success
# [PYTHON] Example 74/90 - Success
# [PYTHON] Example 75/90 - Success
# [PYTHON] Example 76/90 - Success
# [PYTHON] Example 77/90 - Success
# [PYTHON] Example 78/90 - Success
# [PYTHON] Example 79/90 - Success
# [PYTHON] Example 80/90 - Success
# [PYTHON] Example 81/90 - Success
# [PYTHON] Example 82/90 - Success
# [PYTHON] Example 83/90 - Success
# [PYTHON] Example 84/90 - Success
# [PYTHON] Example 85/90 - Success
# [PYTHON] Example 86/90 - Success
# [PYTHON] Example 87/90 - Success
# [PYTHON] Example 88/90 - Success
# [PYTHON] Example 89/90 - Success
# [PYTHON] Example 90/90 - Success
# Saved: Phase-2-Data/python.json
#
# Generating for: SQL
# [SQL] Example 51/90 - Success
# [SQL] Example 52/90 - Success
# [SQL] Example 53/90 - Success
# [SQL] Example 54/90 - Success
# [SQL] Example 55/90 - Success
# [SQL] Example 56/90 - Success
# [SQL] Example 57/90 - Success
# [SQL] Example 58/90 - Success
# [SQL] Example 59/90 - Success
# [SQL] Example 60/90 - Success
# [SQL] Example 61/90 - Success
# [SQL] Example 62/90 - Success
# [SQL] Example 63/90 - Success
# [SQL] Example 64/90 - Success
# [SQL] Example 65/90 - Success
# [SQL] Example 66/90 - Success
# [SQL] Example 67/90 - Success
# [SQL] Example 68/90 - Success
# [SQL] Example 69/90 - Success
# [SQL] Example 70/90 - Success
# [SQL] Example 71/90 - Success
# [SQL] Example 72/90 - Success
# [SQL] Example 73/90 - Success
# [SQL] Example 74/90 - Success
# [SQL] Example 75/90 - Success
# [SQL] Example 76/90 - Success
# [SQL] Example 77/90 - Success
# [SQL] Example 78/90 - Success
# [SQL] Example 79/90 - Success
# [SQL] Example 80/90 - Success
# [SQL] Example 81/90 - Success
# [SQL] Example 82/90 - Success
# [SQL] Example 83/90 - Success
# [SQL] Example 84/90 - Success
# [SQL] Example 85/90 - Success
# [SQL] Example 86/90 - Success
# [SQL] Example 87/90 - Success
# [SQL] Example 88/90 - Success
# [SQL] Example 89/90 - Success
# [SQL] Example 90/90 - Success
# Saved: Phase-2-Data/sql.json
#
# Generating for: C#
# [C#] Example 51/90 - Success
# [C#] Example 52/90 - Success
# [C#] Example 53/90 - Success
# [C#] Example 54/90 - Success
# Retrying [C#] Example 55 due to: Expecting ',' delimiter: line 2 column 918 (char 919)
# [C#] Example 55/90 - Success
# [C#] Example 56/90 - Success
# [C#] Example 57/90 - Success
# Retrying [C#] Example 58 due to: Expecting ',' delimiter: line 2 column 753 (char 754)
# [C#] Example 58/90 - Success
# [C#] Example 59/90 - Success
# [C#] Example 60/90 - Success
# [C#] Example 61/90 - Success
# [C#] Example 62/90 - Success
# [C#] Example 63/90 - Success
# [C#] Example 64/90 - Success
# [C#] Example 65/90 - Success
# [C#] Example 66/90 - Success
# [C#] Example 67/90 - Success
# [C#] Example 68/90 - Success
# [C#] Example 69/90 - Success
# [C#] Example 70/90 - Success
# [C#] Example 71/90 - Success
# Retrying [C#] Example 72 due to: Expecting ',' delimiter: line 2 column 685 (char 686)
# [C#] Example 72/90 - Success
# Retrying [C#] Example 73 due to: Expecting ',' delimiter: line 2 column 209 (char 210)
# [C#] Example 73/90 - Success
# [C#] Example 74/90 - Success
# [C#] Example 75/90 - Success
# Retrying [C#] Example 76 due to: Expecting ',' delimiter: line 2 column 162 (char 163)
# [C#] Example 76/90 - Success
# [C#] Example 77/90 - Success
# [C#] Example 78/90 - Success
# [C#] Example 79/90 - Success
# Retrying [C#] Example 80 due to: Expecting ',' delimiter: line 2 column 1311 (char 1312)
# [C#] Example 80/90 - Success
# Retrying [C#] Example 81 due to: Expecting ',' delimiter: line 2 column 202 (char 203)
# [C#] Example 81/90 - Success
# [C#] Example 82/90 - Success
# [C#] Example 83/90 - Success
# [C#] Example 84/90 - Success
# [C#] Example 85/90 - Success
# [C#] Example 86/90 - Success
# [C#] Example 87/90 - Success
# [C#] Example 88/90 - Success
# [C#] Example 89/90 - Success
# [C#] Example 90/90 - Success
# Saved: Phase-2-Data/c#.json
#
# Generating for: JAVASCRIPT
# [JAVASCRIPT] Example 51/90 - Success
# [JAVASCRIPT] Example 52/90 - Success
# [JAVASCRIPT] Example 53/90 - Success
# [JAVASCRIPT] Example 54/90 - Success
# [JAVASCRIPT] Example 55/90 - Success
# [JAVASCRIPT] Example 56/90 - Success
# [JAVASCRIPT] Example 57/90 - Success
# [JAVASCRIPT] Example 58/90 - Success
# [JAVASCRIPT] Example 59/90 - Success
# [JAVASCRIPT] Example 60/90 - Success
# [JAVASCRIPT] Example 61/90 - Success
# [JAVASCRIPT] Example 62/90 - Success
# [JAVASCRIPT] Example 63/90 - Success
# [JAVASCRIPT] Example 64/90 - Success
# [JAVASCRIPT] Example 65/90 - Success
# [JAVASCRIPT] Example 66/90 - Success
# [JAVASCRIPT] Example 67/90 - Success
# [JAVASCRIPT] Example 68/90 - Success
# [JAVASCRIPT] Example 69/90 - Success
# [JAVASCRIPT] Example 70/90 - Success
# [JAVASCRIPT] Example 71/90 - Success
# Retrying [JAVASCRIPT] Example 72 due to: Expecting ',' delimiter: line 2 column 245 (char 246)
# [JAVASCRIPT] Example 72/90 - Success
# [JAVASCRIPT] Example 73/90 - Success
# [JAVASCRIPT] Example 74/90 - Success
# [JAVASCRIPT] Example 75/90 - Success
# [JAVASCRIPT] Example 76/90 - Success
# [JAVASCRIPT] Example 77/90 - Success
# [JAVASCRIPT] Example 78/90 - Success
# [JAVASCRIPT] Example 79/90 - Success
# [JAVASCRIPT] Example 80/90 - Success
# [JAVASCRIPT] Example 81/90 - Success
# [JAVASCRIPT] Example 82/90 - Success
# [JAVASCRIPT] Example 83/90 - Success
# [JAVASCRIPT] Example 84/90 - Success
# [JAVASCRIPT] Example 85/90 - Success
# [JAVASCRIPT] Example 86/90 - Success
# Retrying [JAVASCRIPT] Example 87 due to: Invalid \escape: line 2 column 365 (char 366)
# [JAVASCRIPT] Example 87/90 - Success
# [JAVASCRIPT] Example 88/90 - Success
# [JAVASCRIPT] Example 89/90 - Success
# [JAVASCRIPT] Example 90/90 - Success
# Saved: Phase-2-Data/javascript.json
#
# Generating for: RUBY
# [RUBY] Example 51/90 - Success
# [RUBY] Example 52/90 - Success
# [RUBY] Example 53/90 - Success
# [RUBY] Example 54/90 - Success
# [RUBY] Example 55/90 - Success
# Retrying [RUBY] Example 56 due to: Invalid \escape: line 2 column 172 (char 173)
# [RUBY] Example 56/90 - Success
# [RUBY] Example 57/90 - Success
# [RUBY] Example 58/90 - Success
# Retrying [RUBY] Example 59 due to: Invalid \escape: line 2 column 149 (char 150)
# [RUBY] Example 59/90 - Success
# [RUBY] Example 60/90 - Success
# [RUBY] Example 61/90 - Success
# [RUBY] Example 62/90 - Success
# [RUBY] Example 63/90 - Success
# [RUBY] Example 64/90 - Success
# [RUBY] Example 65/90 - Success
# [RUBY] Example 66/90 - Success
# [RUBY] Example 67/90 - Success
# [RUBY] Example 68/90 - Success
# [RUBY] Example 69/90 - Success
# [RUBY] Example 70/90 - Success
# [RUBY] Example 71/90 - Success
# [RUBY] Example 72/90 - Success
# [RUBY] Example 73/90 - Success
# [RUBY] Example 74/90 - Success
# Retrying [RUBY] Example 75 due to: Invalid \escape: line 2 column 715 (char 716)
# [RUBY] Example 75/90 - Success
# [RUBY] Example 76/90 - Success
# [RUBY] Example 77/90 - Success
# [RUBY] Example 78/90 - Success
# [RUBY] Example 79/90 - Success
# [RUBY] Example 80/90 - Success
# [RUBY] Example 81/90 - Success
# [RUBY] Example 82/90 - Success
# [RUBY] Example 83/90 - Success
# [RUBY] Example 84/90 - Success
# [RUBY] Example 85/90 - Success
# [RUBY] Example 86/90 - Success
# [RUBY] Example 87/90 - Success
# [RUBY] Example 88/90 - Success
# [RUBY] Example 89/90 - Success
# [RUBY] Example 90/90 - Success
# Saved: Phase-2-Data/ruby.json
#
# Generating for: TYPESCRIPT
# [TYPESCRIPT] Example 51/90 - Success
# [TYPESCRIPT] Example 52/90 - Success
# [TYPESCRIPT] Example 53/90 - Success
# [TYPESCRIPT] Example 54/90 - Success
# [TYPESCRIPT] Example 55/90 - Success
# [TYPESCRIPT] Example 56/90 - Success
# [TYPESCRIPT] Example 57/90 - Success
# [TYPESCRIPT] Example 58/90 - Success
# [TYPESCRIPT] Example 59/90 - Success
# [TYPESCRIPT] Example 60/90 - Success
# [TYPESCRIPT] Example 61/90 - Success
# [TYPESCRIPT] Example 62/90 - Success
# [TYPESCRIPT] Example 63/90 - Success
# [TYPESCRIPT] Example 64/90 - Success
# [TYPESCRIPT] Example 65/90 - Success
# [TYPESCRIPT] Example 66/90 - Success
# [TYPESCRIPT] Example 67/90 - Success
# [TYPESCRIPT] Example 68/90 - Success
# [TYPESCRIPT] Example 69/90 - Success
# [TYPESCRIPT] Example 70/90 - Success
# [TYPESCRIPT] Example 71/90 - Success
# [TYPESCRIPT] Example 72/90 - Success
# [TYPESCRIPT] Example 73/90 - Success
# [TYPESCRIPT] Example 74/90 - Success
# [TYPESCRIPT] Example 75/90 - Success
# [TYPESCRIPT] Example 76/90 - Success
# [TYPESCRIPT] Example 77/90 - Success
# [TYPESCRIPT] Example 78/90 - Success
# [TYPESCRIPT] Example 79/90 - Success
# [TYPESCRIPT] Example 80/90 - Success
# [TYPESCRIPT] Example 81/90 - Success
# [TYPESCRIPT] Example 82/90 - Success
# [TYPESCRIPT] Example 83/90 - Success
# [TYPESCRIPT] Example 84/90 - Success
# Retrying [TYPESCRIPT] Example 85 due to: Invalid \escape: line 2 column 424 (char 425)
# [TYPESCRIPT] Example 85/90 - Success
# [TYPESCRIPT] Example 86/90 - Success
# [TYPESCRIPT] Example 87/90 - Success
# [TYPESCRIPT] Example 88/90 - Success
# [TYPESCRIPT] Example 89/90 - Success
# [TYPESCRIPT] Example 90/90 - Success
# Saved: Phase-2-Data/typescript.json
#
# Generating for: C++
# [C++] Example 51/90 - Success
# [C++] Example 52/90 - Success
# [C++] Example 53/90 - Success
# [C++] Example 54/90 - Success
# [C++] Example 55/90 - Success
# [C++] Example 56/90 - Success
# [C++] Example 57/90 - Success
# [C++] Example 58/90 - Success
# [C++] Example 59/90 - Success
# [C++] Example 60/90 - Success
# [C++] Example 61/90 - Success
# [C++] Example 62/90 - Success
# [C++] Example 63/90 - Success
# [C++] Example 64/90 - Success
# [C++] Example 65/90 - Success
# [C++] Example 66/90 - Success
# [C++] Example 67/90 - Success
# [C++] Example 68/90 - Success
# [C++] Example 69/90 - Success
# [C++] Example 70/90 - Success
# [C++] Example 71/90 - Success
# [C++] Example 72/90 - Success
# [C++] Example 73/90 - Success
# [C++] Example 74/90 - Success
# [C++] Example 75/90 - Success
# [C++] Example 76/90 - Success
# [C++] Example 77/90 - Success
# [C++] Example 78/90 - Success
# [C++] Example 79/90 - Success
# [C++] Example 80/90 - Success
# [C++] Example 81/90 - Success
# [C++] Example 82/90 - Success
# [C++] Example 83/90 - Success
# [C++] Example 84/90 - Success
# [C++] Example 85/90 - Success
# [C++] Example 86/90 - Success
# [C++] Example 87/90 - Success
# [C++] Example 88/90 - Success
# [C++] Example 89/90 - Success
# [C++] Example 90/90 - Success
# Saved: Phase-2-Data/c++.json
#
# Generating for: KOTLIN
# [KOTLIN] Example 51/90 - Success
# [KOTLIN] Example 52/90 - Success
# Retrying [KOTLIN] Example 53 due to: Invalid \escape: line 2 column 252 (char 253)
# [KOTLIN] Example 53/90 - Failed: Expecting ',' delimiter: line 2 column 356 (char 357)
# [KOTLIN] Example 54/90 - Success
# [KOTLIN] Example 55/90 - Success
# Retrying [KOTLIN] Example 56 due to: Invalid \escape: line 2 column 586 (char 587)
# [KOTLIN] Example 56/90 - Failed: Invalid \escape: line 2 column 502 (char 503)
# [KOTLIN] Example 57/90 - Success
# Retrying [KOTLIN] Example 58 due to: Invalid \escape: line 2 column 231 (char 232)
# [KOTLIN] Example 58/90 - Success
# [KOTLIN] Example 59/90 - Success
# [KOTLIN] Example 60/90 - Success
# Retrying [KOTLIN] Example 61 due to: Invalid \escape: line 2 column 138 (char 139)
# [KOTLIN] Example 61/90 - Failed: Invalid \escape: line 2 column 294 (char 295)
# [KOTLIN] Example 62/90 - Success
# [KOTLIN] Example 63/90 - Success
# [KOTLIN] Example 64/90 - Success
# [KOTLIN] Example 65/90 - Success
# [KOTLIN] Example 66/90 - Success
# Retrying [KOTLIN] Example 67 due to: Invalid \escape: line 2 column 365 (char 366)
# [KOTLIN] Example 67/90 - Success
# Retrying [KOTLIN] Example 68 due to: Invalid \escape: line 2 column 255 (char 256)
# [KOTLIN] Example 68/90 - Success
# Retrying [KOTLIN] Example 69 due to: Invalid \escape: line 2 column 377 (char 378)
# [KOTLIN] Example 69/90 - Failed: Invalid \escape: line 2 column 371 (char 372)
# Retrying [KOTLIN] Example 70 due to: Invalid \escape: line 2 column 255 (char 256)
# [KOTLIN] Example 70/90 - Failed: Invalid \escape: line 2 column 248 (char 249)
# [KOTLIN] Example 71/90 - Success
# [KOTLIN] Example 72/90 - Success
# [KOTLIN] Example 73/90 - Success
# [KOTLIN] Example 74/90 - Success
# [KOTLIN] Example 75/90 - Success
# [KOTLIN] Example 76/90 - Success
# Retrying [KOTLIN] Example 77 due to: Invalid \escape: line 2 column 324 (char 325)
# [KOTLIN] Example 77/90 - Failed: Invalid \escape: line 2 column 664 (char 665)
# Retrying [KOTLIN] Example 78 due to: Invalid \escape: line 2 column 357 (char 358)
# [KOTLIN] Example 78/90 - Failed: Invalid \escape: line 2 column 282 (char 283)
# Retrying [KOTLIN] Example 79 due to: Invalid \escape: line 2 column 255 (char 256)
# [KOTLIN] Example 79/90 - Success
# [KOTLIN] Example 80/90 - Success
# Retrying [KOTLIN] Example 81 due to: Invalid \escape: line 2 column 435 (char 436)
# [KOTLIN] Example 81/90 - Success
# [KOTLIN] Example 82/90 - Success
# [KOTLIN] Example 83/90 - Success
# [KOTLIN] Example 84/90 - Success
# [KOTLIN] Example 85/90 - Success
# [KOTLIN] Example 86/90 - Success
# Retrying [KOTLIN] Example 87 due to: Invalid \escape: line 2 column 302 (char 303)
# [KOTLIN] Example 87/90 - Failed: Invalid \escape: line 2 column 256 (char 257)
# [KOTLIN] Example 88/90 - Success
# Retrying [KOTLIN] Example 89 due to: Invalid \escape: line 2 column 348 (char 349)
# [KOTLIN] Example 89/90 - Success
# [KOTLIN] Example 90/90 - Success
# Saved: Phase-2-Data/kotlin.json
#
# Generating for: RUST
# Retrying [RUST] Example 51 due to: Expecting property name enclosed in double quotes: line 2 column 425 (char 426)
# [RUST] Example 51/90 - Success
# [RUST] Example 52/90 - Success
# [RUST] Example 53/90 - Success
# [RUST] Example 54/90 - Success
# [RUST] Example 55/90 - Success
# [RUST] Example 56/90 - Success
# [RUST] Example 57/90 - Success
# [RUST] Example 58/90 - Success
# Retrying [RUST] Example 59 due to: Expecting ',' delimiter: line 2 column 612 (char 613)
# [RUST] Example 59/90 - Failed: Expecting ',' delimiter: line 2 column 863 (char 864)
# [RUST] Example 60/90 - Success
# [RUST] Example 61/90 - Success
# [RUST] Example 62/90 - Success
# [RUST] Example 63/90 - Success
# [RUST] Example 64/90 - Success
# [RUST] Example 65/90 - Success
# [RUST] Example 66/90 - Success
# [RUST] Example 67/90 - Success
# [RUST] Example 68/90 - Success
# [RUST] Example 69/90 - Success
# [RUST] Example 70/90 - Success
# [RUST] Example 71/90 - Success
# [RUST] Example 72/90 - Success
# [RUST] Example 73/90 - Success
# Retrying [RUST] Example 74 due to: Invalid \escape: line 2 column 323 (char 324)
# [RUST] Example 74/90 - Success
# Retrying [RUST] Example 75 due to: Expecting ',' delimiter: line 2 column 615 (char 616)
# [RUST] Example 75/90 - Success
# [RUST] Example 76/90 - Success
# [RUST] Example 77/90 - Success
# [RUST] Example 78/90 - Success
# Retrying [RUST] Example 79 due to: Expecting ',' delimiter: line 2 column 854 (char 855)
# [RUST] Example 79/90 - Success
# [RUST] Example 80/90 - Success
# [RUST] Example 81/90 - Success
# [RUST] Example 82/90 - Success
# [RUST] Example 83/90 - Success
# [RUST] Example 84/90 - Success
# [RUST] Example 85/90 - Success
# [RUST] Example 86/90 - Success
# [RUST] Example 87/90 - Success
# [RUST] Example 88/90 - Success
# [RUST] Example 89/90 - Success
# [RUST] Example 90/90 - Success
# Saved: Phase-2-Data/rust.json
#
# Generating for: GO
# [GO] Example 51/90 - Success
# [GO] Example 52/90 - Success
# [GO] Example 53/90 - Success
# [GO] Example 54/90 - Success
# [GO] Example 55/90 - Success
# [GO] Example 56/90 - Success
# [GO] Example 57/90 - Success
# [GO] Example 58/90 - Success
# [GO] Example 59/90 - Success
# [GO] Example 60/90 - Success
# [GO] Example 61/90 - Success
# [GO] Example 62/90 - Success
# [GO] Example 63/90 - Success
# [GO] Example 64/90 - Success
# [GO] Example 65/90 - Success
# [GO] Example 66/90 - Success
# [GO] Example 67/90 - Success
# [GO] Example 68/90 - Success
# [GO] Example 69/90 - Success
# [GO] Example 70/90 - Success
# [GO] Example 71/90 - Success
# [GO] Example 72/90 - Success
# [GO] Example 73/90 - Success
# [GO] Example 74/90 - Success
# [GO] Example 75/90 - Success
# [GO] Example 76/90 - Success
# [GO] Example 77/90 - Success
# [GO] Example 78/90 - Success
# [GO] Example 79/90 - Success
# [GO] Example 80/90 - Success
# [GO] Example 81/90 - Success
# [GO] Example 82/90 - Success
# [GO] Example 83/90 - Success
# [GO] Example 84/90 - Success
# [GO] Example 85/90 - Success
# [GO] Example 86/90 - Success
# [GO] Example 87/90 - Success
# [GO] Example 88/90 - Success
# [GO] Example 89/90 - Success
# [GO] Example 90/90 - Success
# Saved: Phase-2-Data/go.json
#
# Generating for: PHP
# [PHP] Example 51/90 - Success
# [PHP] Example 52/90 - Success
# [PHP] Example 53/90 - Success
# [PHP] Example 54/90 - Success
# [PHP] Example 55/90 - Success
# [PHP] Example 56/90 - Success
# [PHP] Example 57/90 - Success
# [PHP] Example 58/90 - Success
# [PHP] Example 59/90 - Success
# [PHP] Example 60/90 - Success
# [PHP] Example 61/90 - Success
# [PHP] Example 62/90 - Success
# [PHP] Example 63/90 - Success
# [PHP] Example 64/90 - Success
# [PHP] Example 65/90 - Success
# [PHP] Example 66/90 - Success
# [PHP] Example 67/90 - Success
# [PHP] Example 68/90 - Success
# [PHP] Example 69/90 - Success
# [PHP] Example 70/90 - Success
# [PHP] Example 71/90 - Success
# [PHP] Example 72/90 - Success
# [PHP] Example 73/90 - Success
# [PHP] Example 74/90 - Success
# [PHP] Example 75/90 - Success
# [PHP] Example 76/90 - Success
# [PHP] Example 77/90 - Success
# [PHP] Example 78/90 - Success
# [PHP] Example 79/90 - Success
# [PHP] Example 80/90 - Success
# [PHP] Example 81/90 - Success
# [PHP] Example 82/90 - Success
# [PHP] Example 83/90 - Success
# [PHP] Example 84/90 - Success
# [PHP] Example 85/90 - Success
# [PHP] Example 86/90 - Success
# [PHP] Example 87/90 - Success
# [PHP] Example 88/90 - Success
# [PHP] Example 89/90 - Success
# [PHP] Example 90/90 - Success
# Saved: Phase-2-Data/php.json
#
# Generating for: SCALA
# [SCALA] Example 51/90 - Success
# [SCALA] Example 52/90 - Success
# [SCALA] Example 53/90 - Success
# [SCALA] Example 54/90 - Success
# [SCALA] Example 55/90 - Success
# [SCALA] Example 56/90 - Success
# [SCALA] Example 57/90 - Success
# [SCALA] Example 58/90 - Success
# [SCALA] Example 59/90 - Success
# [SCALA] Example 60/90 - Success
# [SCALA] Example 61/90 - Success
# [SCALA] Example 62/90 - Success
# [SCALA] Example 63/90 - Success
# [SCALA] Example 64/90 - Success
# [SCALA] Example 65/90 - Success
# [SCALA] Example 66/90 - Success
# [SCALA] Example 67/90 - Success
# [SCALA] Example 68/90 - Success
# [SCALA] Example 69/90 - Success
# Retrying [SCALA] Example 70 due to: Invalid \escape: line 2 column 405 (char 406)
# [SCALA] Example 70/90 - Success
# [SCALA] Example 71/90 - Success
# [SCALA] Example 72/90 - Success
# [SCALA] Example 73/90 - Success
# [SCALA] Example 74/90 - Success
# [SCALA] Example 75/90 - Success
# [SCALA] Example 76/90 - Success
# [SCALA] Example 77/90 - Success
# [SCALA] Example 78/90 - Success
# [SCALA] Example 79/90 - Success
# [SCALA] Example 80/90 - Success
# [SCALA] Example 81/90 - Success
# [SCALA] Example 82/90 - Success
# [SCALA] Example 83/90 - Success
# [SCALA] Example 84/90 - Success
# [SCALA] Example 85/90 - Success
# [SCALA] Example 86/90 - Success
# [SCALA] Example 87/90 - Success
# [SCALA] Example 88/90 - Success
# [SCALA] Example 89/90 - Success
# [SCALA] Example 90/90 - Success
# Saved: Phase-2-Data/scala.json
