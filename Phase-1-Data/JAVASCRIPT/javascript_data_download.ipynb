# %%
from datasets import load_dataset, DownloadMode

# First, download the dataset with caching
def download_starcoderdata_js(save_directory, split="train", download_mode=DownloadMode.REUSE_DATASET_IF_EXISTS):
    try:
        ds = load_dataset(
            "bigcode/starcoderdata",
            data_dir="javascript",
            split=split,
            cache_dir=save_directory,
            download_mode=download_mode,
        )

        # Save the dataset properly for later reloading
        output_path = f"{save_directory}/js_{split}_dataset"
        ds.save_to_disk(output_path)

        print(f"Dataset 'bigcode/starcoderdata' (JAVASCRIPT, {split}) successfully downloaded and saved to '{output_path}'.")
        return ds

    except Exception as e:
        print(f"Error downloading dataset 'bigcode/starcoderdata' (JAVASCRIPT, {split}): {e}")
        return None

# %%
ds = download_starcoderdata_js(save_directory="./", split="train")
# Out:
# README.md:   0%|          | 0.00/3.39k [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/65 [00:00<?, ?it/s]
# ...
# train-00000-of-00065.parquet:   0%|          | 0.00/390M [00:00<?, ?B/s]
# train-00001-of-00065.parquet:   0%|          | 0.00/389M [00:00<?, ?B/s]
# train-00002-of-00065.parquet:   0%|          | 0.00/380M [00:00<?, ?B/s]
# train-00003-of-00065.parquet:   0%|          | 0.00/382M [00:00<?, ?B/s]
# train-00004-of-00065.parquet:   0%|          | 0.00/382M [00:00<?, ?B/s]
# train-00005-of-00065.parquet:   0%|          | 0.00/386M [00:00<?, ?B/s]
# train-00006-of-00065.parquet:   0%|          | 0.00/383M [00:00<?, ?B/s]
# train-00007-of-00065.parquet:   0%|          | 0.00/385M [00:00<?, ?B/s]
# train-00008-of-00065.parquet:   0%|          | 0.00/389M [00:00<?, ?B/s]
# train-00009-of-00065.parquet:   0%|          | 0.00/378M [00:00<?, ?B/s]
# train-00010-of-00065.parquet:   0%|          | 0.00/387M [00:00<?, ?B/s]
# ...

# %%
from datasets import load_from_disk

# Later, load the dataset from the saved location
dataset = load_from_disk("./js_train_dataset")
# Out:
# Loading dataset from disk:   0%|          | 0/135 [00:00<?, ?it/s]

# %%
dataset
# Out:
# Dataset({
#     features: ['max_stars_repo_path', 'max_stars_repo_name', 'max_stars_count', 'id', 'content'],
#     num_rows: 19544285
# })

# %%
type(dataset)
# Out:
# datasets.arrow_dataset.Dataset

# %%
print(dataset[0])
# Out:
# {'max_stars_repo_path': 'bids-validator/validators/bids/obj.js', 'max_stars_repo_name': 'olgn/bids-validator', 'max_stars_count': 0, 'id': '0', 'content': '<reponame>olgn/bids-validator<filename>bids-validator/validators/bids/obj.js\nmodule.exports = {\n  options: {},\n  issues: [],\n  summary: {\n    sessions: [],\n    subjects: [],\n    tasks: [],\n    modalities: [],\n    totalFiles: [],\n    size: 0,\n  },\n}\n'}

# %%
dataset = dataset.sort(column_names=["max_stars_count", "max_stars_repo_name"], reverse=[True, False])

# %%
# Print the first 10 examples
for i, example in enumerate(dataset):
    if i < 10:
        print(f"Example {i}:")
        print(example['content'])
        print("\n")
    else:
        break
# Out:
# Example 0:
# <reponame>Rewats/vue<gh_stars>1000+
# import { getRoot, fireEvent, compileAndExecute } from '../helpers/index'
#
# describe('generate attribute', () => {
#   it('should be generated', (done) => {
#     compileAndExecute(`
#       <div>
#         <text value="Hello World" style="font-size: 100"></text>
#       </div>
#     `).then(instance => {
#       expect(getRoot(instance)).toEqual({
#         type: 'div',
#         children: [{
#           type: 'text',
#           style: { fontSize: '100' },
#           attr: { value: 'Hello World' }
#         }]
#       })
#       done()
#     }).catch(e => done.fail(e))
#   })
#
#   it('should be updated', (done) => {
#     compileAndExecute(`
#       <div @click="foo">
#         <text :value="x"></text>
#       </div>
#     `, `
#       data: { x: 'Hello World' },
#       methods: {
#         foo: function () {
#           this.x = 'Hello Vue'
#         }
#       }
#     `).then(instance => {
# ...

# %%
from datasets import Dataset

def calculate_avg_line_length(example):
    lines = example['content'].split('\n')
    avg_length = sum(len(line) for line in lines) / len(lines)
    example['avg_line_length'] = avg_length
    return example

dataset = dataset.map(calculate_avg_line_length)

for i, example in enumerate(dataset):
    if i < 10:
        print(f"Example {i}:")
        print(example['content'])
        print(f"Average Line Length: {example['avg_line_length']}\n")
    else:
        break
# Out:
# Map:   0%|          | 0/19544285 [00:00<?, ? examples/s]
# Example 0:
# <reponame>Rewats/vue<gh_stars>1000+
# import { getRoot, fireEvent, compileAndExecute } from '../helpers/index'
#
# describe('generate attribute', () => {
#   it('should be generated', (done) => {
#     compileAndExecute(`
#       <div>
#         <text value="Hello World" style="font-size: 100"></text>
#       </div>
#     `).then(instance => {
#       expect(getRoot(instance)).toEqual({
#         type: 'div',
#         children: [{
#           type: 'text',
#           style: { fontSize: '100' },
#           attr: { value: 'Hello World' }
#         }]
#       })
#       done()
#     }).catch(e => done.fail(e))
#   })
#
#   it('should be updated', (done) => {
#     compileAndExecute(`
#       <div @click="foo">
#         <text :value="x"></text>
#       </div>
#     `, `
#       data: { x: 'Hello World' },
#       methods: {
#         foo: function () {
#           this.x = 'Hello Vue'
#         }
#       }
# ...

# %%
sliced_dataset = dataset[:2500000]

# %%
del dataset

# %%
import pandas as pd

df = pd.DataFrame(sliced_dataset)

# %%
avg_line_length_stats = df['avg_line_length'].describe()
print("Statistics for avg_line_length:")
print(avg_line_length_stats)
# Out:
# Statistics for avg_line_length:
# count    2.500000e+06
# mean     2.790790e+01
# std      1.055807e+01
# min      8.000000e-01
# 25%      2.166154e+01
# 50%      2.619453e+01
# 75%      3.160714e+01
# max      1.340000e+02
# Name: avg_line_length, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.boxplot(x=df['avg_line_length'])
plt.title('Boxplot of Average Line Length')
plt.xlabel('Average Line Length')
plt.show()

# %%
Q1 = df['avg_line_length'].quantile(0.25)
Q3 = df['avg_line_length'].quantile(0.75)
IQR = Q3 - Q1

# %%
outliers = df[(df['avg_line_length'] < (Q1 - 1.5 * IQR)) | (df['avg_line_length'] > (Q3 + 1.5 * IQR))]
print(f"Number of outliers: {len(outliers)}")
# Out:
# Number of outliers: 117039

# %%
outliers['avg_line_length'].describe()
# Out:
# count    117039.000000
# mean         60.727316
# std          15.466976
# min           0.800000
# 25%          50.196564
# 50%          56.888889
# 75%          70.137147
# max         134.000000
# Name: avg_line_length, dtype: float64

# %%
df.drop(outliers.index, inplace=True)

# %%
df['avg_line_length'].describe()
# Out:
# count    2.382961e+06
# mean     2.629598e+01
# std      7.049647e+00
# min      6.744444e+00
# 25%      2.143478e+01
# 50%      2.579167e+01
# 75%      3.066667e+01
# max      4.652542e+01
# Name: avg_line_length, dtype: float64

# %%
import numpy as np

np.percentile(df['avg_line_length'], 80)
# Out:
# 32.0

# %%
df['line_count'] = df['content'].apply(lambda x: len(x.split('\n')))
df['line_count'].describe()
# Out:
# count    2.382961e+06
# mean     1.078892e+02
# std      4.989125e+02
# min      1.000000e+00
# 25%      1.800000e+01
# 50%      4.200000e+01
# 75%      9.800000e+01
# max      9.345900e+04
# Name: line_count, dtype: float64

# %%
count_range_dict = {
    "0-100": 0,
    "101-200": 0,
    "201-300": 0,
    "301-400": 0,
    "401-500": 0,
    "501-600": 0,
    "601-700": 0,
    "701-800": 0,
    "801-900": 0,
    "901-1000": 0,
    "1000+": 0
}

for count in df['line_count']:
    if count <= 100:
        count_range_dict["0-100"] += 1
    elif count <= 200:
        count_range_dict["101-200"] += 1
    elif count <= 300:
        count_range_dict["201-300"] += 1
    elif count <= 400:
        count_range_dict["301-400"] += 1
    elif count <= 500:
        count_range_dict["401-500"] += 1
    elif count <= 600:
        count_range_dict["501-600"] += 1
    elif count <= 700:
        count_range_dict["601-700"] += 1
    elif count <= 800:
        count_range_dict["701-800"] += 1
    elif count <= 900:
        count_range_dict["801-900"] += 1
    elif count <= 1000:
        count_range_dict["901-1000"] += 1
    else:
        count_range_dict["1000+"] += 1

# %%
for key, value in count_range_dict.items():
    print(f"Number of examples with line count in range {key}: {value}")
# Out:
# Number of examples with line count in range 0-100: 1805255
# Number of examples with line count in range 101-200: 323478
# Number of examples with line count in range 201-300: 111329
# Number of examples with line count in range 301-400: 50877
# Number of examples with line count in range 401-500: 27285
# Number of examples with line count in range 501-600: 16433
# Number of examples with line count in range 601-700: 10658
# Number of examples with line count in range 701-800: 7278
# Number of examples with line count in range 801-900: 5041
# Number of examples with line count in range 901-1000: 3851
# Number of examples with line count in range 1000+: 21476

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.figure(figsize=(12, 6))
sns.barplot(x=list(count_range_dict.keys()), y=list(count_range_dict.values()))
plt.title("Distribution of JS code lengths")
plt.xlabel("Length of JS code")
plt.ylabel("Number of examples")
plt.xticks(rotation=45)
plt.show()

# %%
df_line = pd.DataFrame(list(count_range_dict.items()), columns=["Length", "Count"])
df_line["Cumulative Count"] = df_line["Count"].cumsum()
df_line["Percentage"] = df_line["Count"] / df_line["Count"].sum() * 100
df_line["Cumulative Percentage"] = df_line["Percentage"].cumsum()
df_line.head(11)
# Out:
#       Length    Count  Cumulative Count  Percentage  Cumulative Percentage
# 0      0-100  1805255           1805255   75.756800              75.756800
# 1    101-200   323478           2128733   13.574624              89.331424
# 2    201-300   111329           2240062    4.671877              94.003301
# 3    301-400    50877           2290939    2.135033              96.138334
# 4    401-500    27285           2318224    1.145004              97.283338
# 5    501-600    16433           2334657    0.689604              97.972942
# 6    601-700    10658           2345315    0.447259              98.420201
# 7    701-800     7278           2352593    0.305418              98.725619
# 8    801-900     5041           2357634    0.211544              98.937163
# 9   901-1000     3851           2361485    0.161606              99.098768
# 10     1000+    21476           2382961    0.901232             100.000000

# %%
np.percentile(df['line_count'], 90)
# Out:
# 210.0

# %%
df.columns
# Out:
# Index(['max_stars_repo_path', 'max_stars_repo_name', 'max_stars_count', 'id',
#        'content', 'avg_line_length', 'line_count'],
#       dtype='object')

# %%
df_filtered = df.drop(columns=['max_stars_repo_path', 'max_stars_repo_name', 'max_stars_count', 'id'], axis=1)
df_filtered.head()
# Out:
#                                              content  avg_line_length  \
# 0  <reponame>Rewats/vue<gh_stars>1000+\nimport { ...        22.769231
# 1  <gh_stars>1000+\n({\n  type: 'recycle-list',\n...        17.775000
# 2  try {\n  var vueVersion = require('vue').versi...        28.857143
# 3  <gh_stars>1000+\n({\n  type: 'div',\n  childre...        14.523810
# 4  <filename>test/unit/modules/observer/dep.spec....        20.184615
#
#    line_count
# 0          91
# 1          40
# 2          21
# 3          21
# 4          65

# %%
df_filtered.shape
# Out:
# (2382961, 3)

# %%
df_filtered = df_filtered[df_filtered['line_count'] <= 210]
df_filtered.shape
# Out:
# (2144992, 3)

# %%
df_filtered = df_filtered[df_filtered['avg_line_length'] <= 32]
df_filtered.shape
# Out:
# (1750650, 3)

# %%
df_filtered.head()
# Out:
#                                              content  avg_line_length  \
# 0  <reponame>Rewats/vue<gh_stars>1000+\nimport { ...        22.769231
# 1  <gh_stars>1000+\n({\n  type: 'recycle-list',\n...        17.775000
# 2  try {\n  var vueVersion = require('vue').versi...        28.857143
# 3  <gh_stars>1000+\n({\n  type: 'div',\n  childre...        14.523810
# 4  <filename>test/unit/modules/observer/dep.spec....        20.184615
#
#    line_count
# 0          91
# 1          40
# 2          21
# 3          21
# 4          65

# %%
print(df[["avg_line_length", "line_count"]].describe())
print()
print(df_filtered.describe())
# Out:
#        avg_line_length    line_count
# count     2.382961e+06  2.382961e+06
# mean      2.629598e+01  1.078892e+02
# std       7.049647e+00  4.989125e+02
# min       6.744444e+00  1.000000e+00
# 25%       2.143478e+01  1.800000e+01
# 50%       2.579167e+01  4.200000e+01
# 75%       3.066667e+01  9.800000e+01
# max       4.652542e+01  9.345900e+04
#
#        avg_line_length    line_count
# count     1.750650e+06  1.750650e+06
# mean      2.344621e+01  5.053125e+01
# std       4.957992e+00  4.612738e+01
# min       6.744444e+00  1.000000e+00
# 25%       2.012000e+01  1.600000e+01
# 50%       2.383333e+01  3.500000e+01
# 75%       2.728571e+01  7.100000e+01
# max       3.200000e+01  2.100000e+02

# %%
data_dict_js = {}

for i, example in enumerate(df_filtered["content"]):
    data_dict_js[f"js_{i}"] = example

# %%
assert len(data_dict_js) == len(df_filtered), "Data dictionary length does not match the number of examples in the dataset."

# %%
for i, (k,v) in enumerate(data_dict_js.items()):
    if i < 5:
        print(f"Example {k}:")
        print(v)
        print("\n")
    else:
        break
# Out:
# Example js_0:
# <reponame>Rewats/vue<gh_stars>1000+
# import { getRoot, fireEvent, compileAndExecute } from '../helpers/index'
#
# describe('generate attribute', () => {
#   it('should be generated', (done) => {
#     compileAndExecute(`
#       <div>
#         <text value="Hello World" style="font-size: 100"></text>
#       </div>
#     `).then(instance => {
#       expect(getRoot(instance)).toEqual({
#         type: 'div',
#         children: [{
#           type: 'text',
#           style: { fontSize: '100' },
#           attr: { value: 'Hello World' }
#         }]
#       })
#       done()
#     }).catch(e => done.fail(e))
#   })
#
#   it('should be updated', (done) => {
#     compileAndExecute(`
#       <div @click="foo">
#         <text :value="x"></text>
#       </div>
#     `, `
#       data: { x: 'Hello World' },
#       methods: {
#         foo: function () {
#           this.x = 'Hello Vue'
#         }
#       }
#     `).then(instance => {
# ...

# %%
import json

with open('js_train.json', 'w') as f:
    json.dump(data_dict_js, f)
    print("Saved to 'js_train.json'")
# Out:
# Saved to 'js_train.json'
